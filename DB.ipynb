# %% [markdown]
# # Requirement

# %%
# !pip install pyyaml
# !pip install tqdm
# !pip install tensorboardX
# !pip install opencv-python
# !pip install anyconfig
# !pip install munch
# !pip install scipy
# !pip install sortedcontainers
# !pip install shapely==2.0.3
# !pip install pyclipper
# !pip install gevent
# !pip install gevent_websocket
# !pip install flask
# !pip install editdistance
# !pip install scikit-image
# !pip install imgaug==0.4
# !pip install numpy==1.23
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.6/237.6 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for anyconfig: filename=anyconfig-0.14.0-py2.py3-none-any.whl size=98062 sha256=cb648dceaa6f491366aa16d1a67b1bf76dc3ce006ebb7b4e2e1342e8ddd943d9
#   Stored in directory: /root/.cache/pip/wheels/64/e8/42/ce517be872aecd407d8846d24f9c894bc1df7086cdd23e9507
# Successfully built anyconfig
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 15.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.0.4
#     Uninstalling shapely-2.0.4:
#       Successfully uninstalled shapely-2.0.4
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 24.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Setup

# %%
# !echo $CUDA_HOME

# %%
# %cd /content/drive/MyDrive/DB/assets/ops/dcn/
# !python setup.py build_ext --inplace

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/DB/
# Out:
# /content/drive/MyDrive/DB

# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %%
# !python train.py experiments/seg_detector/totaltext_resnet50_deform_thre.yaml
# Out:
# [INFO] [2024-04-24 07:22:53,138] Training epoch 0
# [INFO] [2024-04-24 07:24:01,690] step:      0, epoch:   0, loss: 24.904976, lr: 0.007000
# [INFO] [2024-04-24 07:24:01,693] bce_loss: 4.018536
# [INFO] [2024-04-24 07:24:01,694] thresh_loss: 0.957206
# [INFO] [2024-04-24 07:24:01,694] l1_loss: 0.385509
# [INFO] [2024-04-24 07:28:02,695] Training epoch 1

# %%
# !python eval.py experiments/seg_detector/totaltext_resnet50_deform_thre.yaml --resume trained_models/totaltext_resnet50 --polygon --box_thresh 0.6
